# %%
import pandas as pd
from nltk.corpus import stopwords
from gensim import corpora, models, similarities, utils, matutils
from sklearn.naive_bayes import BernoulliNB
from sklearn.cross_validation import cross_val_score

# %%
df_all_topics = pd.read_csv('pubmed_data', usecols= ['pid', 'title', 'abstract', 'topic_id', 'sr_title', 'rel'])

# %%
df_all_topics.head()
# Out:
#        pid                                              title  \
# 0  3903849  [Nonvisualization of the gallbladder lumen by ...
# 1  3903849  [Nonvisualization of the gallbladder lumen by ...
# 2  3903849  [Nonvisualization of the gallbladder lumen by ...
# 3  1559484                                    Cholangioscopy.
# 4  1559484                                    Cholangioscopy.
#
#                                             abstract  topic_id  \
# 0  Out of 12 000 sonographic examinations of the ...  CD011548
# 1  Out of 12 000 sonographic examinations of the ...  CD011549
# 2  Out of 12 000 sonographic examinations of the ...  CD010339
# 3                                                NaN  CD011548
# 4                                                NaN  CD011549
#
#                                             sr_title  rel
# 0  Ultrasound versus liver function tests for dia...    0
# 1  Endoscopic ultrasound versus magnetic resonanc...    0
# 2  Endoscopic retrograde cholangiopancreatography...    0
# 3  Ultrasound versus liver function tests for dia...    0
# 4  Endoscopic ultrasound versus magnetic resonanc...    0

# %%
df_all_topics.set_index(["topic_id", "pid"]).count(level="topic_id").sort_values(by = ["title"])
# Out:
#           title  abstract  sr_title    rel
# topic_id
# CD008760     64        56        64     64
# CD010860     94        92        94     94
# CD010705    114       112       114    114
# CD010896    169       159       169    169
# CD010775    241       221       241    241
# CD010772    316       307       316    316
# CD010771    318       309       318    318
# CD010542    348       338       348    348
# CD010386    625       579       625    625
# CD009135    791       702       791    791
# CD008081    970       902       970    970
# CD010023    981       859       981    981
# CD009944   1165       984      1165   1165
# CD008691   1310      1248      1310   1310
# CD007427   1472      1454      1472   1472
# CD010632   1501      1483      1501   1501
# CD010633   1573      1464      1573   1573
# CD009020   1576      1466      1576   1576
# CD009185   1615      1278      1615   1615
# CD009551   1911      1879      1911   1911
# CD011134   1938      1792      1938   1938
# CD009786   2065      1813      2065   2065
# CD007431   2074      1922      2074   2074
# CD009372   2248      2054      2248   2248
# CD007394   2542      2372      2542   2542
# CD009647   2785      2641      2785   2785
# CD008054   3146      2959      3146   3146
# CD010438   3241      2356      3241   3241
# CD009323   3855      3630      3855   3855
# CD008686   3951      3803      3951   3951
# CD008803   5220      4691      5220   5220
# CD010173   5495      4671      5495   5495
# CD010276   5495      4671      5495   5495
# CD009519   5971      4800      5971   5971
# CD009579   6455      4792      6455   6455
# CD009925   6531      5276      6531   6531
# CD009591   7990      7117      7990   7990
# CD010653   8002      7701      8002   8002
# CD011984   8180      6738      8180   8180
# CD011975   8186      6743      8186   8186
# CD012019  10317      8833     10317  10317
# CD008782  10507      9347     10507  10507
# CD011145  10872     10787     10872  10872
# CD010783  10905     10820     10905  10905
# CD011548  12700      9253     12700  12700
# CD011549  12700      9253     12700  12700
# CD010339  12803      9339     12803  12803
# CD009593  14908     12670     14908  14908
# CD008643  15071     13620     15071  15071
# CD010409  43335     29312     43335  43335

# %%
def generate_corpus(df_topics):
    #primero creamos el dicionario    
    stop_words = stopwords.words('english')
    dictionary = corpora.Dictionary()
    for index, row in df_topics.iterrows():
        if type(row['abstract']) == str:  # revisamos si tenemos el abstract (no estan todos)
            title = list(filter(lambda x : x not in stop_words, utils.tokenize(row['title'], lowercase = True)))
            abstract = list(filter(lambda x : x not in stop_words, utils.tokenize(row['abstract'], lowercase = True)))
            dictionary.add_documents([title,abstract]) 
    #luego transformamos las palabras segun el diccionario
    corpus = []
    for index, row in df_topics.iterrows():
        if type(row['abstract']) == str: # revisamos si tenemos el abstract (no estan todos)
            title = list(filter(lambda x : x  not in stop_words, utils.tokenize(row['title'], lowercase=True))) 
            abstract = list(filter(lambda x : x  not in stop_words, utils.tokenize(row['abstract'], lowercase=True)))
            corpus.append(dictionary.doc2bow(title+abstract))
    
    print("dictionary len: {0}".format(len(dictionary)))
    
    return corpus, dictionary

# %%
 df_specific_topic = df_all_topics[df_all_topics['topic_id'] == "CD009944"]

# %%
 df_specific_topic.head()
# Out:
#             pid                                              title  \
# 1685    4588237                   Radiology of the biliary system.
# 6680    3517700  [Is it still useful to integrate cholecystogra...
# 6915    3052732  [Sonographic appearance of adenomyomatosis of ...
# 19632  21902990  Large abdominal wall endometrioma following la...
# 24666   2203297  Adenomyomatosis of the gall bladder: the NUH e...
#
#                                                 abstract  topic_id  \
# 1685                                                 NaN  CD009591
# 6680   There are discordant opinions in literature on...  CD009591
# 6915                                                 NaN  CD009591
# 19632  Endometriosis is a common condition in women t...  CD009591
# 24666  Adenomyomatosis (AD) is a degenerative disorde...  CD009591
#
#                                                 sr_title  rel
# 1685   Imaging modalities for the non-invasive diagno...    0
# 6680   Imaging modalities for the non-invasive diagno...    0
# 6915   Imaging modalities for the non-invasive diagno...    0
# 19632  Imaging modalities for the non-invasive diagno...    0
# 24666  Imaging modalities for the non-invasive diagno...    0

# %%
corpus , dictionary = generate_corpus( df_all_topics)

# %%
dictionary.token2id

# %%
corpora.MmCorpus.serialize('./corpus_df_all_topics.mm', corpus)
dictionary.save('./dictionary_df_all_topics.dict')

# %%
corpus = corpora.MmCorpus('./corpus_df_all_topics.mm')
dictionary = corpora.Dictionary.load('./dictionary_df_all_topics.dict')
len(dictionary)
# Out:
# 119464

# %%
lsi = models.lsimodel.LsiModel(corpus=corpus, id2word=dictionary, num_topics=400)
lsi.print_topics(10)
# Out:
# [(0,
#   '0.670*"patients" + 0.172*"disease" + 0.140*"study" + 0.138*"p" + 0.121*"treatment" + 0.118*"cases" + 0.111*"clinical" + 0.101*"cancer" + 0.089*"group" + 0.085*"diagnosis"'),
#  (1,
#   '0.540*"patients" + -0.342*"cells" + -0.266*"cell" + -0.170*"lymph" + -0.147*"expression" + -0.137*"p" + -0.129*"cases" + -0.126*"cancer" + -0.122*"cd" + -0.111*"tumor"'),
#  (2,
#   '-0.320*"ad" + -0.292*"disease" + 0.288*"lymph" + -0.229*"cognitive" + -0.215*"alzheimer" + 0.199*"cancer" + 0.191*"node" + -0.181*"dementia" + 0.169*"nodes" + 0.157*"cells"'),
#  (3,
#   '-0.324*"patients" + 0.296*"duct" + 0.250*"cases" + 0.244*"bile" + -0.234*"lymph" + 0.178*"common" + 0.174*"stones" + -0.159*"node" + 0.154*"diagnosis" + 0.152*"laparoscopic"'),
#  (4,
#   '0.444*"cells" + -0.313*"cancer" + -0.240*"lymph" + 0.240*"cell" + 0.203*"cd" + -0.194*"node" + 0.170*"p" + 0.165*"patients" + 0.146*"duct" + -0.135*"nodes"'),
#  (5,
#   '0.397*"disease" + 0.296*"ad" + -0.286*"p" + 0.223*"duct" + 0.209*"alzheimer" + 0.205*"lymph" + 0.179*"bile" + -0.153*"tuberculosis" + -0.130*"tb" + 0.122*"nodes"'),
#  (6,
#   '0.587*"p" + -0.311*"tuberculosis" + -0.231*"tb" + 0.199*"duct" + -0.194*"cells" + 0.163*"bile" + -0.160*"treatment" + 0.134*"cancer" + -0.127*"disease" + -0.118*"patients"'),
#  (7,
#   '0.411*"tuberculosis" + 0.307*"tb" + 0.278*"p" + -0.273*"cases" + 0.256*"treatment" + -0.180*"syndrome" + 0.165*"cancer" + -0.136*"cells" + -0.132*"patients" + 0.128*"duct"'),
#  (8,
#   '0.316*"lymph" + -0.232*"pain" + 0.207*"tuberculosis" + 0.203*"nodes" + 0.190*"node" + -0.172*"treatment" + 0.165*"tb" + -0.155*"endometriosis" + 0.149*"screening" + -0.149*"cell"'),
#  (9,
#   '-0.600*"cases" + 0.293*"cancer" + -0.287*"p" + 0.197*"cells" + -0.192*"tuberculosis" + -0.188*"disease" + -0.161*"tb" + 0.132*"cognitive" + 0.121*"study" + 0.120*"screening"')]

# %%
lsi.save('./lsi_model_400.model')

# %%
lsi = models.lsimodel.LsiModel(corpus=corpus, id2word=dictionary, num_topics=600)
lsi.print_topics(10)
# Out:
# [(0,
#   '0.670*"patients" + 0.172*"disease" + 0.140*"study" + 0.138*"p" + 0.121*"treatment" + 0.118*"cases" + 0.111*"clinical" + 0.101*"cancer" + 0.089*"group" + 0.085*"diagnosis"'),
#  (1,
#   '0.540*"patients" + -0.342*"cells" + -0.266*"cell" + -0.170*"lymph" + -0.147*"expression" + -0.137*"p" + -0.128*"cases" + -0.127*"cancer" + -0.122*"cd" + -0.111*"tumor"'),
#  (2,
#   '-0.320*"ad" + -0.291*"disease" + 0.289*"lymph" + -0.229*"cognitive" + -0.215*"alzheimer" + 0.199*"cancer" + 0.192*"node" + -0.181*"dementia" + 0.169*"nodes" + 0.156*"cells"'),
#  (3,
#   '-0.324*"patients" + 0.296*"duct" + 0.250*"cases" + 0.244*"bile" + -0.235*"lymph" + 0.179*"common" + 0.174*"stones" + -0.159*"node" + 0.154*"diagnosis" + 0.152*"laparoscopic"'),
#  (4,
#   '0.444*"cells" + -0.312*"cancer" + 0.241*"cell" + -0.240*"lymph" + 0.203*"cd" + -0.194*"node" + 0.170*"p" + 0.166*"patients" + 0.144*"duct" + -0.135*"nodes"'),
#  (5,
#   '0.395*"disease" + 0.297*"ad" + -0.280*"p" + 0.225*"duct" + 0.209*"alzheimer" + 0.206*"lymph" + 0.181*"bile" + -0.155*"tuberculosis" + -0.131*"tb" + 0.122*"common"'),
#  (6,
#   '0.588*"p" + -0.312*"tuberculosis" + -0.230*"tb" + 0.196*"duct" + -0.194*"cells" + 0.161*"bile" + -0.159*"treatment" + 0.133*"cancer" + -0.130*"disease" + -0.117*"patients"'),
#  (7,
#   '0.413*"tuberculosis" + 0.308*"tb" + 0.279*"p" + -0.270*"cases" + 0.252*"treatment" + -0.180*"syndrome" + 0.164*"cancer" + -0.138*"cells" + -0.132*"patients" + 0.129*"duct"'),
#  (8,
#   '0.317*"lymph" + -0.232*"pain" + 0.206*"tuberculosis" + 0.204*"nodes" + 0.190*"node" + -0.173*"treatment" + 0.163*"tb" + -0.154*"endometriosis" + 0.149*"screening" + -0.149*"cell"'),
#  (9,
#   '-0.590*"cases" + 0.357*"cancer" + -0.303*"p" + -0.168*"tuberculosis" + 0.153*"cells" + -0.148*"lymph" + 0.147*"screening" + -0.141*"tb" + 0.136*"oral" + 0.134*"women"')]

# %%
lsi.save('./lsi_model_600.model')

# %%
def get_reduced_data(df_specific_topic, dictionary, lsi):
    labels = []
    corpus = []
    stop_words = stopwords.words('english')
    for index, row in df_specific_topic.iterrows():
            if type(row['abstract']) == str: # revisamos si tenemos el abstract (no estan todos)
                title = list(filter(lambda x : x  not in stop_words, utils.tokenize(row['title'], lowercase=True))) 
                abstract = list(filter(lambda x : x  not in stop_words, utils.tokenize(row['abstract'], lowercase=True)))
                corpus.append(list(x[1] for x in lsi[dictionary.doc2bow(title+abstract)]))
                labels.append(row['rel'])
    
    
    return labels, corpus

# %%
labels, new_corpus = get_reduced_data(df_specific_topic, dictionary, lsi)

# %%
print(new_corpus[0])
print(len(labels))
print(type(labels))
print(type(new_corpus[0]))
# Out:
# [2.835565884254884, -0.7801260130393838, 2.338088738909797, 3.744501663012928, -1.1477247056721143, 2.3316716113140936, 0.8892436159019634, 2.006987281369657, -0.5177147445211432, 0.8038350661655081, -0.10872442411494598, -0.08007151210413711, -1.221210918668494, 0.13100386968298258, -1.0698500664229647, -1.3761389657679628, -0.7928385299271155, 1.1984319457578345, -2.1118969232893634, 0.21057790174054317, -1.4354748260852914, 0.849396560319428, -0.4838991008863585, 0.2897066436440419, 0.6115861364089227, 1.5856519293574982, -1.03952927441068, -0.5266480324008895, 1.987232440707245, 1.8976949610200438, 0.1388826048945927, -0.953269941618747, 0.24586480043553946, -0.8873748752284141, -1.0821882305029629, 0.457914503799375, -1.538625695218549, 0.8763333645609368, -0.4725193074448676, -0.6843014453901273, -0.4553317973719866, 1.5381158539273823, 0.154344170862252, -0.7703468418929709, -0.260217303079703, -0.34940869026685406, -0.08291765049693979, -0.5705677849684244, -0.8633780911613059, 0.12455295741106598, 0.16195058546353874, 0.5466308868167535, 0.2824810885241767, 